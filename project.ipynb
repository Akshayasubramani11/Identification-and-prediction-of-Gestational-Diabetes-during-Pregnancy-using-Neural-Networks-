# %% [markdown]
# #### IMPORTING THE NECESSARY LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectKBest, f_classif
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, Flatten, LSTM, Dense, Concatenate, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\A.GOWTHAMI\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\A.GOWTHAMI\anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\A.GOWTHAMI\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# Set random seed for NumPy
np.random.seed(42)

# Set random seed for TensorFlow
tf.random.set_seed(42)

# %% [markdown]
# #### IMPORTING THE DATASET

# %%
data = pd.read_csv("GestationalDiabetesDataset.csv")

# %% [markdown]
# #### READING THE DATASET

# %%
data
# Out:
#       Case Number  Age  No of Pregnancy  Gestation in previous Pregnancy  \
# 0               1   22                2                                1
# 1               2   26                2                                1
# 2               3   29                1                                0
# 3               4   28                2                                1
# 4               5   21                2                                1
# ...           ...  ...              ...                              ...
# 3520         3521   31                4                                1
# 3521         3522   26                3                                1
# 3522         3523   35                2                                2
# 3523         3524   37                2                                0
# 3524         3525   43                2                                0
#
#        BMI   HDL  Family History  unexplained prenetal loss  \
# 0      NaN  55.0               0                          0
# 1      NaN  53.0               0                          0
# 2      NaN  50.0               0                          0
# 3      NaN  51.0               0                          0
# 4      NaN  52.0               0                          0
# ...    ...   ...             ...                        ...
# 3520  24.1  32.0               0                          0
# 3521  34.5  43.0               1                          1
# 3522  23.6  56.0               1                          0
# 3523  23.3  28.0               1                          0
# 3524  28.6  30.0               1                          1
#
#       Large Child or Birth Default  PCOS  Sys BP  Dia BP   OGTT  Hemoglobin  \
# 0                                0     0   102.0      69    NaN        12.0
# 1                                0     0   101.0      63    NaN        12.4
# 2                                0     0   118.0      79    NaN        14.3
# 3                                0     0    99.0      70    NaN        15.0
# 4                                0     0   116.0      65    NaN        15.0
# ...                            ...   ...     ...     ...    ...         ...
# 3520                             1     0   150.0     107  187.0        13.4
# 3521                             0     1   166.0      85  164.0        14.2
# 3522                             1     0   178.0      81  141.0        15.3
# 3523                             1     1   139.0     115  133.0        13.3
# 3524                             0     0   121.0      63  179.0        15.8
#
#       Sedentary Lifestyle  Prediabetes  Class Label(GDM /Non GDM)
# 0                       0            0                          0
# 1                       0            0                          0
# 2                       0            0                          0
# 3                       0            0                          0
# 4                       0            0                          0
# ...                   ...          ...                        ...
# 3520                    1            1                          1
# 3521                    0            0                          1
# 3522                    0            1                          1
# 3523                    0            1                          0
# 3524                    1            0                          0
#
# [3525 rows x 17 columns]

# %% [markdown]
# #### EXPLORATORY DATA ANALYSIS

# %%
data.head()
# Out:
#    Case Number  Age  No of Pregnancy  Gestation in previous Pregnancy  BMI  \
# 0            1   22                2                                1  NaN
# 1            2   26                2                                1  NaN
# 2            3   29                1                                0  NaN
# 3            4   28                2                                1  NaN
# 4            5   21                2                                1  NaN
#
#     HDL  Family History  unexplained prenetal loss  \
# 0  55.0               0                          0
# 1  53.0               0                          0
# 2  50.0               0                          0
# 3  51.0               0                          0
# 4  52.0               0                          0
#
#    Large Child or Birth Default  PCOS  Sys BP  Dia BP  OGTT  Hemoglobin  \
# 0                             0     0   102.0      69   NaN        12.0
# 1                             0     0   101.0      63   NaN        12.4
# 2                             0     0   118.0      79   NaN        14.3
# 3                             0     0    99.0      70   NaN        15.0
# 4                             0     0   116.0      65   NaN        15.0
#
#    Sedentary Lifestyle  Prediabetes  Class Label(GDM /Non GDM)
# 0                    0            0                          0
# 1                    0            0                          0
# 2                    0            0                          0
# 3                    0            0                          0
# 4                    0            0                          0

# %%
data.tail()
# Out:
#       Case Number  Age  No of Pregnancy  Gestation in previous Pregnancy  \
# 3520         3521   31                4                                1
# 3521         3522   26                3                                1
# 3522         3523   35                2                                2
# 3523         3524   37                2                                0
# 3524         3525   43                2                                0
#
#        BMI   HDL  Family History  unexplained prenetal loss  \
# 3520  24.1  32.0               0                          0
# 3521  34.5  43.0               1                          1
# 3522  23.6  56.0               1                          0
# 3523  23.3  28.0               1                          0
# 3524  28.6  30.0               1                          1
#
#       Large Child or Birth Default  PCOS  Sys BP  Dia BP   OGTT  Hemoglobin  \
# 3520                             1     0   150.0     107  187.0        13.4
# 3521                             0     1   166.0      85  164.0        14.2
# 3522                             1     0   178.0      81  141.0        15.3
# 3523                             1     1   139.0     115  133.0        13.3
# 3524                             0     0   121.0      63  179.0        15.8
#
#       Sedentary Lifestyle  Prediabetes  Class Label(GDM /Non GDM)
# 3520                    1            1                          1
# 3521                    0            0                          1
# 3522                    0            1                          1
# 3523                    0            1                          0
# 3524                    1            0                          0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3525 entries, 0 to 3524
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Case Number                      3525 non-null   int64
#  1   Age                              3525 non-null   int64
#  2   No of Pregnancy                  3525 non-null   int64
#  3   Gestation in previous Pregnancy  3525 non-null   int64
#  4   BMI                              2444 non-null   float64
#  5   HDL                              2524 non-null   float64
#  6   Family History                   3525 non-null   int64
#  7   unexplained prenetal loss        3525 non-null   int64
#  8   Large Child or Birth Default     3525 non-null   int64
#  9   PCOS                             3525 non-null   int64
#  10  Sys BP                           1820 non-null   float64
#  11  Dia BP                           3525 non-null   int64
#  12  OGTT                             3012 non-null   float64
#  13  Hemoglobin                       3525 non-null   float64
#  14  Sedentary Lifestyle              3525 non-null   int64
#  15  Prediabetes                      3525 non-null   int64
#  16  Class Label(GDM /Non GDM)        3525 non-null   int64
# dtypes: float64(5), int64(12)
# memory usage: 468.3 KB

# %%
data.columns
# Out:
# Index(['Case Number', 'Age', 'No of Pregnancy',
#        'Gestation in previous Pregnancy', 'BMI', 'HDL', 'Family History',
#        'unexplained prenetal loss', 'Large Child or Birth Default', 'PCOS',
#        'Sys BP', 'Dia BP', 'OGTT', 'Hemoglobin', 'Sedentary Lifestyle',
#        'Prediabetes', 'Class Label(GDM /Non GDM)'],
#       dtype='object')

# %%
data.shape
# Out:
# (3525, 17)

# %%
data.nunique()
# Out:
# Case Number                        3525
# Age                                  26
# No of Pregnancy                       4
# Gestation in previous Pregnancy       3
# BMI                                 272
# HDL                                  56
# Family History                        2
# unexplained prenetal loss             2
# Large Child or Birth Default          2
# PCOS                                  2
# Sys BP                               96
# Dia BP                               65
# OGTT                                252
# Hemoglobin                           88
# Sedentary Lifestyle                   2
# Prediabetes                           2
# Class Label(GDM /Non GDM)             2
# dtype: int64

# %%
data.count()
# Out:
# Case Number                        3525
# Age                                3525
# No of Pregnancy                    3525
# Gestation in previous Pregnancy    3525
# BMI                                2444
# HDL                                2524
# Family History                     3525
# unexplained prenetal loss          3525
# Large Child or Birth Default       3525
# PCOS                               3525
# Sys BP                             1820
# Dia BP                             3525
# OGTT                               3012
# Hemoglobin                         3525
# Sedentary Lifestyle                3525
# Prediabetes                        3525
# Class Label(GDM /Non GDM)          3525
# dtype: int64

# %%
data.dtypes
# Out:
# Case Number                          int64
# Age                                  int64
# No of Pregnancy                      int64
# Gestation in previous Pregnancy      int64
# BMI                                float64
# HDL                                float64
# Family History                       int64
# unexplained prenetal loss            int64
# Large Child or Birth Default         int64
# PCOS                                 int64
# Sys BP                             float64
# Dia BP                               int64
# OGTT                               float64
# Hemoglobin                         float64
# Sedentary Lifestyle                  int64
# Prediabetes                          int64
# Class Label(GDM /Non GDM)            int64
# dtype: object

# %% [markdown]
# #### STATISTICAL ANALYSIS

# %%
data.describe()
# Out:
#        Case Number          Age  No of Pregnancy  \
# count  3525.000000  3525.000000      3525.000000
# mean   1763.000000    32.581277         2.076312
# std    1017.724177     6.169107         0.838637
# min       1.000000    20.000000         1.000000
# 25%     882.000000    28.000000         1.000000
# 50%    1763.000000    32.000000         2.000000
# 75%    2644.000000    37.000000         3.000000
# max    3525.000000    45.000000         4.000000
#
#        Gestation in previous Pregnancy          BMI          HDL  \
# count                      3525.000000  2444.000000  2524.000000
# mean                          0.960851    27.854092    46.471870
# std                           0.722313     5.714737    10.800813
# min                           0.000000    13.300000    15.000000
# 25%                           0.000000    24.400000    42.000000
# 50%                           1.000000    27.500000    49.000000
# 75%                           1.000000    31.000000    55.000000
# max                           2.000000    45.000000    70.000000
#
#        Family History  unexplained prenetal loss  \
# count     3525.000000                3525.000000
# mean         0.498156                   0.364823
# std          0.500068                   0.481449
# min          0.000000                   0.000000
# 25%          0.000000                   0.000000
# 50%          0.000000                   0.000000
# 75%          1.000000                   1.000000
# max          1.000000                   1.000000
#
#        Large Child or Birth Default         PCOS       Sys BP       Dia BP  \
# count                    3525.00000  3525.000000  1820.000000  3525.000000
# mean                        0.35773     0.264681   135.762088    81.538156
# std                         0.47940     0.441226    22.742844    11.379758
# min                         0.00000     0.000000    90.000000    60.000000
# 25%                         0.00000     0.000000   122.000000    74.000000
# 50%                         0.00000     0.000000   132.000000    81.000000
# 75%                         1.00000     1.000000   153.000000    86.000000
# max                         1.00000     1.000000   185.000000   124.000000
#
#               OGTT   Hemoglobin  Sedentary Lifestyle  Prediabetes  \
# count  3012.000000  3525.000000          3525.000000  3525.000000
# mean    170.707503    13.959801             0.449645     0.293050
# std      48.160549     1.863969             0.497529     0.455226
# min      80.000000     8.800000             0.000000     0.000000
# 25%     142.000000    12.700000             0.000000     0.000000
# 50%     156.000000    14.000000             0.000000     0.000000
# 75%     195.000000    15.000000             1.000000     1.000000
# max     403.000000    18.000000             1.000000     1.000000
#
#        Class Label(GDM /Non GDM)
# count                3525.000000
# mean                    0.389220
# std                     0.487643
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     1.000000
# max                     1.000000

# %%
np.mean(data)
# Out:
# Case Number                        1763.000000
# Age                                  32.581277
# No of Pregnancy                       2.076312
# Gestation in previous Pregnancy       0.960851
# BMI                                  27.854092
# HDL                                  46.471870
# Family History                        0.498156
# unexplained prenetal loss             0.364823
# Large Child or Birth Default          0.357730
# PCOS                                  0.264681
# Sys BP                              135.762088
# Dia BP                               81.538156
# OGTT                                170.707503
# Hemoglobin                           13.959801
# Sedentary Lifestyle                   0.449645
# Prediabetes                           0.293050
# Class Label(GDM /Non GDM)             0.389220
# dtype: float64

# %%
data.median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of       Case Number  Age  No of Pregnancy  Gestation in previous Pregnancy  \
# 0               1   22                2                                1
# 1               2   26                2                                1
# 2               3   29                1                                0
# 3               4   28                2                                1
# 4               5   21                2                                1
# ...           ...  ...              ...                              ...
# 3520         3521   31                4                                1
# 3521         3522   26                3                                1
# 3522         3523   35                2                                2
# 3523         3524   37                2                                0
# 3524         3525   43                2                                0
#
#        BMI   HDL  Family History  unexplained prenetal loss  \
# 0      NaN  55.0               0                          0
# 1      NaN  53.0               0                          0
# 2      NaN  50.0               0                          0
# 3      NaN  51.0               0                          0
# 4      NaN  52.0               0                          0
# ...    ...   ...             ...                        ...
# 3520  24.1  32.0               0                          0
# 3521  34.5  43.0               1                          1
# 3522  23.6  56.0               1                          0
# 3523  23.3  28.0               1                          0
# 3524  28.6  30.0               1                          1
#
#       Large Child or Birth Default  PCOS  Sys BP  Dia BP   OGTT  Hemoglobin  \
# 0                                0     0   102.0      69    NaN        12.0
# 1                                0     0   101.0      63    NaN        12.4
# 2                                0     0   118.0      79    NaN        14.3
# 3                                0     0    99.0      70    NaN        15.0
# 4                                0     0   116.0      65    NaN        15.0
# ...                            ...   ...     ...     ...    ...         ...
# 3520                             1     0   150.0     107  187.0        13.4
# 3521                             0     1   166.0      85  164.0        14.2
# 3522                             1     0   178.0      81  141.0        15.3
# 3523                             1     1   139.0     115  133.0        13.3
# 3524                             0     0   121.0      63  179.0        15.8
#
#       Sedentary Lifestyle  Prediabetes  Class Label(GDM /Non GDM)
# 0                       0            0                          0
# 1                       0            0                          0
# 2                       0            0                          0
# 3                       0            0                          0
# 4                       0            0                          0
# ...                   ...          ...                        ...
# 3520                    1            1                          1
# 3521                    0            0                          1
# 3522                    0            1                          1
# 3523                    0            1                          0
# 3524                    1            0                          0
#
# [3525 rows x 17 columns]>

# %%
np.std(data)
# Out:
# Case Number                        1017.579808
# Age                                   6.168232
# No of Pregnancy                       0.838518
# Gestation in previous Pregnancy       0.722210
# BMI                                   5.713568
# HDL                                  10.798673
# Family History                        0.499997
# unexplained prenetal loss             0.481380
# Large Child or Birth Default          0.479332
# PCOS                                  0.441163
# Sys BP                               22.736595
# Dia BP                               11.378144
# OGTT                                 48.152554
# Hemoglobin                            1.863704
# Sedentary Lifestyle                   0.497458
# Prediabetes                           0.455161
# Class Label(GDM /Non GDM)             0.487573
# dtype: float64

# %%
np.var(data)
# Out:
# Case Number                        1.035469e+06
# Age                                3.804708e+01
# No of Pregnancy                    7.031126e-01
# Gestation in previous Pregnancy    5.215879e-01
# BMI                                3.264486e+01
# HDL                                1.166113e+02
# Family History                     2.499966e-01
# unexplained prenetal loss          2.317271e-01
# Large Child or Birth Default       2.297594e-01
# PCOS                               1.946249e-01
# Sys BP                             5.169527e+02
# Dia BP                             1.294622e+02
# OGTT                               2.318668e+03
# Hemoglobin                         3.473394e+00
# Sedentary Lifestyle                2.474644e-01
# Prediabetes                        2.071716e-01
# Class Label(GDM /Non GDM)          2.377278e-01
# dtype: float64

# %%
data.skew()
# Out:
# Case Number                        0.000000
# Age                                0.051001
# No of Pregnancy                    0.317721
# Gestation in previous Pregnancy    0.058879
# BMI                                0.524710
# HDL                               -0.917954
# Family History                     0.007379
# unexplained prenetal loss          0.561863
# Large Child or Birth Default       0.593868
# PCOS                               1.067267
# Sys BP                             0.088163
# Dia BP                             0.694349
# OGTT                               1.495513
# Hemoglobin                         0.187769
# Sedentary Lifestyle                0.202534
# Prediabetes                        0.909737
# Class Label(GDM /Non GDM)          0.454608
# dtype: float64

# %%
data.corr()
# Out:
#                                  Case Number       Age  No of Pregnancy  \
# Case Number                         1.000000  0.389118         0.250554
# Age                                 0.389118  1.000000         0.262048
# No of Pregnancy                     0.250554  0.262048         1.000000
# Gestation in previous Pregnancy     0.376781  0.327148         0.669666
# BMI                                 0.698480  0.516200         0.084370
# HDL                                -0.507670 -0.444572         0.011123
# Family History                      0.150812  0.298882         0.012854
# unexplained prenetal loss           0.147234  0.183008         0.195286
# Large Child or Birth Default        0.365506  0.132220         0.295575
# PCOS                                0.585108  0.425936         0.165494
# Sys BP                              0.642472  0.619515         0.368070
# Dia BP                              0.517167  0.481878         0.144426
# OGTT                                0.574109  0.383144         0.141241
# Hemoglobin                          0.413606  0.288387         0.189648
# Sedentary Lifestyle                 0.047535  0.374130         0.275471
# Prediabetes                         0.621281  0.446573         0.266970
# Class Label(GDM /Non GDM)           0.766450  0.446500         0.206292
#
#                                  Gestation in previous Pregnancy       BMI  \
# Case Number                                             0.376781  0.698480
# Age                                                     0.327148  0.516200
# No of Pregnancy                                         0.669666  0.084370
# Gestation in previous Pregnancy                         1.000000  0.322823
# BMI                                                     0.322823  1.000000
# HDL                                                    -0.188953 -0.694974
# Family History                                          0.189133  0.622366
# unexplained prenetal loss                               0.192041  0.072771
# Large Child or Birth Default                            0.363332  0.310124
# PCOS                                                    0.336144  0.489029
# Sys BP                                                  0.296984  0.245677
# Dia BP                                                  0.254994  0.541788
# OGTT                                                    0.430853  0.758952
# Hemoglobin                                              0.274386  0.220607
# Sedentary Lifestyle                                     0.304835  0.338952
# Prediabetes                                             0.513004  0.524723
# Class Label(GDM /Non GDM)                               0.483954  0.643999
#
#                                       HDL  Family History  \
# Case Number                     -0.507670        0.150812
# Age                             -0.444572        0.298882
# No of Pregnancy                  0.011123        0.012854
# Gestation in previous Pregnancy -0.188953        0.189133
# BMI                             -0.694974        0.622366
# HDL                              1.000000       -0.558879
# Family History                  -0.558879        1.000000
# unexplained prenetal loss       -0.034365        0.115946
# Large Child or Birth Default    -0.324827        0.151305
# PCOS                            -0.581137        0.217634
# Sys BP                          -0.629794        0.274973
# Dia BP                          -0.581466        0.481105
# OGTT                            -0.697259        0.461652
# Hemoglobin                      -0.125162        0.125059
# Sedentary Lifestyle             -0.045741        0.367742
# Prediabetes                     -0.588327        0.408126
# Class Label(GDM /Non GDM)       -0.658695        0.345066
#
#                                  unexplained prenetal loss  \
# Case Number                                       0.147234
# Age                                               0.183008
# No of Pregnancy                                   0.195286
# Gestation in previous Pregnancy                   0.192041
# BMI                                               0.072771
# HDL                                              -0.034365
# Family History                                    0.115946
# unexplained prenetal loss                         1.000000
# Large Child or Birth Default                     -0.016034
# PCOS                                              0.183838
# Sys BP                                            0.196896
# Dia BP                                            0.175423
# OGTT                                              0.092726
# Hemoglobin                                        0.012963
# Sedentary Lifestyle                               0.292324
# Prediabetes                                       0.136128
# Class Label(GDM /Non GDM)                         0.224166
#
#                                  Large Child or Birth Default      PCOS  \
# Case Number                                          0.365506  0.585108
# Age                                                  0.132220  0.425936
# No of Pregnancy                                      0.295575  0.165494
# Gestation in previous Pregnancy                      0.363332  0.336144
# BMI                                                  0.310124  0.489029
# HDL                                                 -0.324827 -0.581137
# Family History                                       0.151305  0.217634
# unexplained prenetal loss                           -0.016034  0.183838
# Large Child or Birth Default                         1.000000  0.413514
# PCOS                                                 0.413514  1.000000
# Sys BP                                               0.440776  0.625282
# Dia BP                                               0.293908  0.528135
# OGTT                                                 0.365887  0.559169
# Hemoglobin                                           0.198790  0.358529
# Sedentary Lifestyle                                  0.234373  0.094986
# Prediabetes                                          0.355582  0.577243
# Class Label(GDM /Non GDM)                            0.347396  0.693538
#
#                                    Sys BP    Dia BP      OGTT  Hemoglobin  \
# Case Number                      0.642472  0.517167  0.574109    0.413606
# Age                              0.619515  0.481878  0.383144    0.288387
# No of Pregnancy                  0.368070  0.144426  0.141241    0.189648
# Gestation in previous Pregnancy  0.296984  0.254994  0.430853    0.274386
# BMI                              0.245677  0.541788  0.758952    0.220607
# HDL                             -0.629794 -0.581466 -0.697259   -0.125162
# Family History                   0.274973  0.481105  0.461652    0.125059
# unexplained prenetal loss        0.196896  0.175423  0.092726    0.012963
# Large Child or Birth Default     0.440776  0.293908  0.365887    0.198790
# PCOS                             0.625282  0.528135  0.559169    0.358529
# Sys BP                           1.000000  0.584059  0.322453    0.331778
# Dia BP                           0.584059  1.000000  0.460497    0.324537
# OGTT                             0.322453  0.460497  1.000000    0.237489
# Hemoglobin                       0.331778  0.324537  0.237489    1.000000
# Sedentary Lifestyle              0.258400  0.025913  0.196469    0.026748
# Prediabetes                      0.561799  0.527843  0.606612    0.570972
# Class Label(GDM /Non GDM)        0.499633  0.579715  0.689855    0.480545
#
#                                  Sedentary Lifestyle  Prediabetes  \
# Case Number                                 0.047535     0.621281
# Age                                         0.374130     0.446573
# No of Pregnancy                             0.275471     0.266970
# Gestation in previous Pregnancy             0.304835     0.513004
# BMI                                         0.338952     0.524723
# HDL                                        -0.045741    -0.588327
# Family History                              0.367742     0.408126
# unexplained prenetal loss                   0.292324     0.136128
# Large Child or Birth Default                0.234373     0.355582
# PCOS                                        0.094986     0.577243
# Sys BP                                      0.258400     0.561799
# Dia BP                                      0.025913     0.527843
# OGTT                                        0.196469     0.606612
# Hemoglobin                                  0.026748     0.570972
# Sedentary Lifestyle                         1.000000     0.166031
# Prediabetes                                 0.166031     1.000000
# Class Label(GDM /Non GDM)                   0.138116     0.740059
#
#                                  Class Label(GDM /Non GDM)
# Case Number                                       0.766450
# Age                                               0.446500
# No of Pregnancy                                   0.206292
# Gestation in previous Pregnancy                   0.483954
# BMI                                               0.643999
# HDL                                              -0.658695
# Family History                                    0.345066
# unexplained prenetal loss                         0.224166
# Large Child or Birth Default                      0.347396
# PCOS                                              0.693538
# Sys BP                                            0.499633
# Dia BP                                            0.579715
# OGTT                                              0.689855
# Hemoglobin                                        0.480545
# Sedentary Lifestyle                               0.138116
# Prediabetes                                       0.740059
# Class Label(GDM /Non GDM)                         1.000000

# %%
data.cov()
# Out:
#                                   Case Number          Age  No of Pregnancy  \
# Case Number                      1.035762e+06  2443.057605       213.848184
# Age                              2.443058e+03    38.057879         1.355743
# No of Pregnancy                  2.138482e+02     1.355743         0.703312
# Gestation in previous Pregnancy  2.769776e+02     1.457780         0.405656
# BMI                              2.816757e+03    19.559143         0.417976
# HDL                             -5.785858e+03   -28.233861         0.095599
# Family History                   7.675312e+01     0.922043         0.005390
# unexplained prenetal loss        7.214217e+01     0.543552         0.078849
# Large Child or Birth Default     1.783295e+02     0.391036         0.118834
# PCOS                             2.627404e+02     1.159384         0.061237
# Sys BP                           1.849872e+04    92.600805         7.366191
# Dia BP                           5.989548e+03    33.829262         1.378330
# OGTT                             2.404487e+04   113.519879         5.740958
# Hemoglobin                       7.846138e+02     3.316165         0.296457
# Sedentary Lifestyle              2.406896e+01     1.148319         0.114939
# Prediabetes                      2.878360e+02     1.254126         0.101921
# Class Label(GDM /Non GDM)        3.803783e+02     1.343215         0.084364
#
#                                  Gestation in previous Pregnancy          BMI  \
# Case Number                                           276.977582  2816.757184
# Age                                                     1.457780    19.559143
# No of Pregnancy                                         0.405656     0.417976
# Gestation in previous Pregnancy                         0.521736     1.407490
# BMI                                                     1.407490    32.658219
# HDL                                                    -1.222833   -62.577431
# Family History                                          0.068316     1.775602
# unexplained prenetal loss                               0.066784     0.200345
# Large Child or Birth Default                            0.125814     0.884987
# PCOS                                                    0.107130     1.357975
# Sys BP                                                  5.625880    25.038261
# Dia BP                                                  2.095989    37.753870
# OGTT                                                   15.021580   220.161490
# Hemoglobin                                              0.369425     2.338050
# Sedentary Lifestyle                                     0.109549     0.953169
# Prediabetes                                             0.168684     1.481590
# Class Label(GDM /Non GDM)                               0.170463     1.826601
#
#                                          HDL  Family History  \
# Case Number                     -5785.857847       76.753121
# Age                               -28.233861        0.922043
# No of Pregnancy                     0.095599        0.005390
# Gestation in previous Pregnancy    -1.222833        0.068316
# BMI                               -62.577431        1.775602
# HDL                               116.657552       -3.008305
# Family History                     -3.008305        0.250068
# unexplained prenetal loss          -0.165162        0.027915
# Large Child or Birth Default       -1.578478        0.036273
# PCOS                               -2.252369        0.048019
# Sys BP                           -198.212337        2.991086
# Dia BP                            -72.638910        2.737797
# OGTT                             -407.532348       11.118133
# Hemoglobin                         -2.364591        0.116569
# Sedentary Lifestyle                -0.241088        0.091493
# Prediabetes                        -2.282679        0.092907
# Class Label(GDM /Non GDM)          -2.657789        0.084146
#
#                                  unexplained prenetal loss  \
# Case Number                                      72.142168
# Age                                               0.543552
# No of Pregnancy                                   0.078849
# Gestation in previous Pregnancy                   0.066784
# BMI                                               0.200345
# HDL                                              -0.165162
# Family History                                    0.027915
# unexplained prenetal loss                         0.231793
# Large Child or Birth Default                     -0.003701
# PCOS                                              0.039052
# Sys BP                                            2.196345
# Dia BP                                            0.961104
# OGTT                                              2.206359
# Hemoglobin                                        0.011633
# Sedentary Lifestyle                               0.070022
# Prediabetes                                       0.029835
# Class Label(GDM /Non GDM)                         0.052629
#
#                                  Large Child or Birth Default        PCOS  \
# Case Number                                        178.329455  262.740352
# Age                                                  0.391036    1.159384
# No of Pregnancy                                      0.118834    0.061237
# Gestation in previous Pregnancy                      0.125814    0.107130
# BMI                                                  0.884987    1.357975
# HDL                                                 -1.578478   -2.252369
# Family History                                       0.036273    0.048019
# unexplained prenetal loss                           -0.003701    0.039052
# Large Child or Birth Default                         0.229825    0.087468
# PCOS                                                 0.087468    0.194680
# Sys BP                                               4.855137    7.039347
# Dia BP                                               1.603401    2.651788
# OGTT                                                 8.694732   12.454301
# Hemoglobin                                           0.177636    0.294865
# Sedentary Lifestyle                                  0.055902    0.020852
# Prediabetes                                          0.077601    0.115943
# Class Label(GDM /Non GDM)                            0.081213    0.149222
#
#                                        Sys BP       Dia BP          OGTT  \
# Case Number                      18498.724967  5989.547957  24044.871637
# Age                                 92.600805    33.829262    113.519879
# No of Pregnancy                      7.366191     1.378330      5.740958
# Gestation in previous Pregnancy      5.625880     2.095989     15.021580
# BMI                                 25.038261    37.753870    220.161490
# HDL                               -198.212337   -72.638910   -407.532348
# Family History                       2.991086     2.737797     11.118133
# unexplained prenetal loss            2.196345     0.961104      2.206359
# Large Child or Birth Default         4.855137     1.603401      8.694732
# PCOS                                 7.039347     2.651788     12.454301
# Sys BP                             517.236935   166.329212    340.547477
# Dia BP                             166.329212   129.498898    259.239583
# OGTT                               340.547477   259.239583   2319.438496
# Hemoglobin                          14.341499     6.883926     21.909774
# Sedentary Lifestyle                  2.843749     0.146715      4.727268
# Prediabetes                          6.324668     2.734417     13.870524
# Class Label(GDM /Non GDM)            5.531184     3.216984     16.548756
#
#                                  Hemoglobin  Sedentary Lifestyle  Prediabetes  \
# Case Number                      784.613848            24.068956   287.835982
# Age                                3.316165             1.148319     1.254126
# No of Pregnancy                    0.296457             0.114939     0.101921
# Gestation in previous Pregnancy    0.369425             0.109549     0.168684
# BMI                                2.338050             0.953169     1.481590
# HDL                               -2.364591            -0.241088    -2.282679
# Family History                     0.116569             0.091493     0.092907
# unexplained prenetal loss          0.011633             0.070022     0.029835
# Large Child or Birth Default       0.177636             0.055902     0.077601
# PCOS                               0.294865             0.020852     0.115943
# Sys BP                            14.341499             2.843749     6.324668
# Dia BP                             6.883926             0.146715     2.734417
# OGTT                              21.909774             4.727268    13.870524
# Hemoglobin                         3.474380             0.024806     0.484485
# Sedentary Lifestyle                0.024806             0.247535     0.037604
# Prediabetes                        0.484485             0.037604     0.207230
# Class Label(GDM /Non GDM)          0.436791             0.033509     0.164284
#
#                                  Class Label(GDM /Non GDM)
# Case Number                                     380.378263
# Age                                               1.343215
# No of Pregnancy                                   0.084364
# Gestation in previous Pregnancy                   0.170463
# BMI                                               1.826601
# HDL                                              -2.657789
# Family History                                    0.084146
# unexplained prenetal loss                         0.052629
# Large Child or Birth Default                      0.081213
# PCOS                                              0.149222
# Sys BP                                            5.531184
# Dia BP                                            3.216984
# OGTT                                             16.548756
# Hemoglobin                                        0.436791
# Sedentary Lifestyle                               0.033509
# Prediabetes                                       0.164284
# Class Label(GDM /Non GDM)                         0.237795

# %% [markdown]
# #### DATA CLEANING

# %%
data.isna().sum()
# Out:
# Case Number                           0
# Age                                   0
# No of Pregnancy                       0
# Gestation in previous Pregnancy       0
# BMI                                1081
# HDL                                1001
# Family History                        0
# unexplained prenetal loss             0
# Large Child or Birth Default          0
# PCOS                                  0
# Sys BP                             1705
# Dia BP                                0
# OGTT                                513
# Hemoglobin                            0
# Sedentary Lifestyle                   0
# Prediabetes                           0
# Class Label(GDM /Non GDM)             0
# dtype: int64

# %% [markdown]
# ##### IMPUTING MISSING VALUES

# %%
from sklearn.impute import SimpleImputer

# Define the columns to impute
datacolumns = ["BMI","HDL","Sys BP","OGTT"]

# Initialize SimpleImputer with mean strategy for specified columns
imputer_mean = SimpleImputer(strategy='mean')

# Perform mean imputation only on specified columns
data[datacolumns] = imputer_mean.fit_transform(data[datacolumns])

print(data.isna().sum())
# Out:
# Case Number                        0
# Age                                0
# No of Pregnancy                    0
# Gestation in previous Pregnancy    0
# BMI                                0
# HDL                                0
# Family History                     0
# unexplained prenetal loss          0
# Large Child or Birth Default       0
# PCOS                               0
# Sys BP                             0
# Dia BP                             0
# OGTT                               0
# Hemoglobin                         0
# Sedentary Lifestyle                0
# Prediabetes                        0
# Class Label(GDM /Non GDM)          0
# dtype: int64

# %%
data = data.drop("Case Number", axis = 1)

# %% [markdown]
# #### DATA PREPROCESSING

# %%
from sklearn.preprocessing import StandardScaler

numerical_features = ['BMI', 'HDL', 'Sys BP', 'OGTT', 'Hemoglobin']

scaler = StandardScaler()

data[numerical_features] = scaler.fit_transform(data[numerical_features])

# %% [markdown]
# #### FEATURE SELECTION

# %%
target = "Class Label(GDM /Non GDM)"

x = data.drop([target], axis=1)
y = data[target]

# %%
# Perform feature selection using SelectKBest
selector = SelectKBest(score_func=f_classif, k=10)  # Adjust the value of k as needed
X_selected = selector.fit_transform(x, y)

# Get the selected feature indices
selected_feature_indices = selector.get_support(indices=True)

# Get the names of the selected features
selected_features = x.columns[selected_feature_indices]

# Print the selected feature names
print("Selected Features:")
print(selected_features)
# Out:
# Selected Features:
# Index(['Age', 'Gestation in previous Pregnancy', 'BMI', 'HDL', 'PCOS',
#        'Sys BP', 'Dia BP', 'OGTT', 'Hemoglobin', 'Prediabetes'],
#       dtype='object')

# %% [markdown]
# #### SPLITTING THE DATASET

# %%
x = data.drop([target], axis=1).values
y = data[target].values

# %%
x_train, x_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.20, random_state=42)

# %% [markdown]
# #### MODEL BUILDING

# %% [markdown]
# ##### FEEDFORWARD NEURAL NETWORK - FNN

# %%
def evaluate_model(model, X_test, y_test):
    # Predict on test data
    y_pred = model.predict(X_test)
    y_pred = np.round(y_pred).astype(int)

    # Calculate accuracy
    accuracy = accuracy_score(y_test, y_pred)
    
    # Calculate precision
    precision = precision_score(y_test, y_pred)
    
    # Calculate recall
    recall = recall_score(y_test, y_pred)
    
    # Calculate F1 score
    f1 = f1_score(y_test, y_pred)
    
    return accuracy, precision, recall, f1

# %%
NUM_EPOCHS = 10
BATCH_SIZE = 32  
NUM_FEATURES = x_train.shape[1]  # Number of selected features after feature selection

# %%
fnn_model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(NUM_FEATURES,)),  # Adjusted input shape
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
fnn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
fnn_model.fit(x_train, y_train, epochs=NUM_EPOCHS, batch_size=BATCH_SIZE, validation_split=0.1)
accuracy, precision, recall, f1= evaluate_model(fnn_model, x_test, y_test)
# Out:
# Epoch 1/10
# 80/80 [==============================] - 1s 5ms/step - loss: 1.1267 - accuracy: 0.6572 - val_loss: 0.4658 - val_accuracy: 0.8085
# Epoch 2/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.3675 - accuracy: 0.8865 - val_loss: 0.3370 - val_accuracy: 0.8794
# Epoch 3/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2755 - accuracy: 0.9149 - val_loss: 0.2831 - val_accuracy: 0.8865
# Epoch 4/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2303 - accuracy: 0.9149 - val_loss: 0.2577 - val_accuracy: 0.8936
# Epoch 5/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2205 - accuracy: 0.9200 - val_loss: 0.2483 - val_accuracy: 0.9184
# Epoch 6/10
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1983 - accuracy: 0.9303 - val_loss: 0.2458 - val_accuracy: 0.9255
# Epoch 7/10
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1882 - accuracy: 0.9346 - val_loss: 0.2401 - val_accuracy: 0.9326
# Epoch 8/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1818 - accuracy: 0.9350 - val_loss: 0.2168 - val_accuracy: 0.9397
# Epoch 9/10
# 80/80 [==============================] - 0s 2ms/step - loss: 0.1667 - accuracy: 0.9452 - val_loss: 0.1969 - val_accuracy: 0.9433
# Epoch 10/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1631 - accuracy: 0.9504 - val_loss: 0.1838 - val_accuracy: 0.9504
# 23/23 [==============================] - 0s 1ms/step

# %%
print("FNN MODEL: \n")
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# FNN MODEL:
#
# Accuracy: 0.9574468085106383
# Precision: 0.9450980392156862
# Recall: 0.9377431906614786
# F1 Score: 0.94140625

# %%
y_pred = fnn_model.predict(x_test)
y_pred = np.round(y_pred).astype(int)
# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
    
# Visualize confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.title("Confusion Matrix")
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.show()
# Out:
# 23/23 [==============================] - 0s 2ms/step

# %% [markdown]
# ##### CONVOLUTIONAL NEURAL NETWORK - CNN

# %%
NUM_EPOCHS = 10
BATCH_SIZE = 32  
NUM_FEATURES = x_train.shape[1]
cnn_model = tf.keras.Sequential([
    tf.keras.layers.Reshape((NUM_FEATURES, 1), input_shape=(NUM_FEATURES,)),  # Add a reshape layer to match the input shape
    tf.keras.layers.Conv1D(64, 3, activation='relu'),  # Convolutional layer with 64 filters and kernel size 3
    tf.keras.layers.MaxPooling1D(2),  # Max pooling layer with pool size 2 
    tf.keras.layers.Flatten(),  # Flatten layer to convert output to 1D 
    tf.keras.layers.Dense(64, activation='relu'),  # Dense hidden layer with 64 units and ReLU activation
    tf.keras.layers.Dense(1, activation='sigmoid')  # Output layer with sigmoid activation for binary classification
])

# Compile the model
cnn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
cnn_model.fit(x_train, y_train, epochs=NUM_EPOCHS, batch_size=BATCH_SIZE, validation_split=0.1)
accuracy, precision, recall, f1 = evaluate_model(cnn_model, x_test, y_test)
# Out:
# Epoch 1/10
# 80/80 [==============================] - 2s 7ms/step - loss: 0.6244 - accuracy: 0.7293 - val_loss: 0.4491 - val_accuracy: 0.7624
# Epoch 2/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2953 - accuracy: 0.9035 - val_loss: 0.2731 - val_accuracy: 0.8936
# Epoch 3/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2561 - accuracy: 0.9054 - val_loss: 0.2391 - val_accuracy: 0.9007
# Epoch 4/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1932 - accuracy: 0.9350 - val_loss: 0.2030 - val_accuracy: 0.9291
# Epoch 5/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1843 - accuracy: 0.9354 - val_loss: 0.2082 - val_accuracy: 0.9149
# Epoch 6/10
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1998 - accuracy: 0.9303 - val_loss: 0.2015 - val_accuracy: 0.9468
# Epoch 7/10
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1662 - accuracy: 0.9484 - val_loss: 0.1940 - val_accuracy: 0.9468
# Epoch 8/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1638 - accuracy: 0.9444 - val_loss: 0.1844 - val_accuracy: 0.9504
# Epoch 9/10
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1528 - accuracy: 0.9574 - val_loss: 0.1626 - val_accuracy: 0.9504
# Epoch 10/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1676 - accuracy: 0.9437 - val_loss: 0.1627 - val_accuracy: 0.9433
# 23/23 [==============================] - 0s 2ms/step

# %%
print("CNN MODEL: \n")
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# CNN MODEL:
#
# Accuracy: 0.9574468085106383
# Precision: 0.9595141700404858
# Recall: 0.9221789883268483
# F1 Score: 0.9404761904761905

# %%
y_pred = cnn_model.predict(x_test)
y_pred = np.round(y_pred).astype(int)
# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
    
# Visualize confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.title("Confusion Matrix")
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.show()
# Out:
# 23/23 [==============================] - 0s 2ms/step

# %% [markdown]
# ##### RECURRENT NEURAL NETWORK - RNN

# %%
X_train_reshaped = x_train.reshape((x_train.shape[0], 1, x_train.shape[1]))
X_test_reshaped = x_test.reshape((x_test.shape[0], 1, x_test.shape[1]))

# %%
rnn_model = tf.keras.Sequential([
    tf.keras.layers.SimpleRNN(64, input_shape=(1, NUM_FEATURES)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
rnn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
rnn_model.fit(X_train_reshaped, y_train, epochs=NUM_EPOCHS, batch_size=BATCH_SIZE, validation_split=0.1)
accuracy, precision, recall, f1 = evaluate_model(rnn_model, X_test_reshaped, y_test)
# Out:
# Epoch 1/10
# 80/80 [==============================] - 2s 7ms/step - loss: 0.6106 - accuracy: 0.6836 - val_loss: 0.5179 - val_accuracy: 0.7270
# Epoch 2/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.4011 - accuracy: 0.8794 - val_loss: 0.3631 - val_accuracy: 0.8901
# Epoch 3/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2904 - accuracy: 0.9240 - val_loss: 0.2943 - val_accuracy: 0.9007
# Epoch 4/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2349 - accuracy: 0.9224 - val_loss: 0.2633 - val_accuracy: 0.9078
# Epoch 5/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.2092 - accuracy: 0.9263 - val_loss: 0.2407 - val_accuracy: 0.9043
# Epoch 6/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1853 - accuracy: 0.9283 - val_loss: 0.2151 - val_accuracy: 0.9113
# Epoch 7/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1691 - accuracy: 0.9405 - val_loss: 0.2025 - val_accuracy: 0.9255
# Epoch 8/10
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1604 - accuracy: 0.9444 - val_loss: 0.1897 - val_accuracy: 0.9291
# Epoch 9/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1457 - accuracy: 0.9492 - val_loss: 0.1808 - val_accuracy: 0.9362
# Epoch 10/10
# 80/80 [==============================] - 0s 3ms/step - loss: 0.1385 - accuracy: 0.9523 - val_loss: 0.1726 - val_accuracy: 0.9326
# 23/23 [==============================] - 0s 2ms/step

# %%
print("RNN MODEL: \n")
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# RNN MODEL:
#
# Accuracy: 0.9546099290780142
# Precision: 0.9518072289156626
# Recall: 0.9221789883268483
# F1 Score: 0.9367588932806324

# %%
y_pred = rnn_model.predict(X_test_reshaped)
y_pred = np.round(y_pred).astype(int)
# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
    
# Visualize confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.title("Confusion Matrix")
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.show()
# Out:
# 23/23 [==============================] - 0s 2ms/step

# %% [markdown]
# ##### HYBRID MODEL - CNN & RNN

# %%
# Define the input shapes for CNN and RNN branches
cnn_input_shape = (x_train.shape[1], 1)
rnn_input_shape = (x_train.shape[1],)

# CNN branch
cnn_input = Input(shape=cnn_input_shape)
cnn_layer = Conv1D(filters=64, kernel_size=3, activation='relu')(cnn_input)
cnn_layer = MaxPooling1D(pool_size=2)(cnn_layer)
cnn_layer = Conv1D(filters=64, kernel_size=3, activation='relu')(cnn_layer)
cnn_layer = MaxPooling1D(pool_size=2)(cnn_layer) 
cnn_layer = Flatten()(cnn_layer)
cnn_layer = Dropout(0.6)(cnn_layer)  # Increased dropout rate

# RNN branch
rnn_input = Input(shape=rnn_input_shape)
rnn_layer = tf.keras.layers.Reshape((1, rnn_input_shape[0]))(rnn_input)  # Reshape for RNN compatibility
rnn_layer = LSTM(128, return_sequences=True)(rnn_layer)
rnn_layer = LSTM(64, return_sequences=True)(rnn_layer)
rnn_layer = LSTM(32, return_sequences=True)(rnn_layer)  # Additional LSTM layer
rnn_layer = LSTM(16)(rnn_layer)  # Additional LSTM layer
rnn_layer = Dropout(0.6)(rnn_layer)  # Increased dropout rate

# Concatenate CNN and RNN branches
concatenated = Concatenate()([cnn_layer, rnn_layer])

# Fully connected layer with L2 regularization
output = Dense(1, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.l2(0.01))(concatenated)

# Create the hybrid model
hybrid_model = Model(inputs=[cnn_input, rnn_input], outputs=output)

# %%
# Compile the model with RMSprop optimizer and adjusted learning rate
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.01)
hybrid_model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Learning rate scheduling
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.01)

# %%
# Train the model with early stopping and learning rate reduction
hybrid_model.fit([x_train, x_train], y_train, epochs=50, batch_size=64, validation_split=0.35,
                            callbacks=[reduce_lr, EarlyStopping(patience=10, restore_best_weights=True)])
# Out:
# Epoch 1/50
# 29/29 [==============================] - 12s 89ms/step - loss: 2.3660 - accuracy: 0.5619 - val_loss: 0.6665 - val_accuracy: 0.6170 - lr: 0.0100
# Epoch 2/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.6900 - accuracy: 0.5985 - val_loss: 0.6739 - val_accuracy: 0.6170 - lr: 0.0100
# Epoch 3/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.6729 - accuracy: 0.6421 - val_loss: 0.6288 - val_accuracy: 0.5836 - lr: 0.0100
# Epoch 4/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.5254 - accuracy: 0.7583 - val_loss: 0.3390 - val_accuracy: 0.8551 - lr: 0.0100
# Epoch 5/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.4364 - accuracy: 0.8205 - val_loss: 0.3221 - val_accuracy: 0.8490 - lr: 0.0100
# Epoch 6/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.3596 - accuracy: 0.8636 - val_loss: 0.3186 - val_accuracy: 0.8501 - lr: 0.0100
# Epoch 7/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.3546 - accuracy: 0.8483 - val_loss: 0.2493 - val_accuracy: 0.8815 - lr: 0.0100
# Epoch 8/50
# 29/29 [==============================] - 0s 14ms/step - loss: 0.2875 - accuracy: 0.9018 - val_loss: 0.3330 - val_accuracy: 0.8561 - lr: 0.0100
# Epoch 9/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.2865 - accuracy: 0.9045 - val_loss: 0.2458 - val_accuracy: 0.9311 - lr: 0.0100
# Epoch 10/50
# 29/29 [==============================] - 0s 14ms/step - loss: 0.2609 - accuracy: 0.9138 - val_loss: 0.1612 - val_accuracy: 0.9433 - lr: 0.0100
# Epoch 11/50
# 29/29 [==============================] - 0s 16ms/step - loss: 0.2592 - accuracy: 0.9143 - val_loss: 0.1653 - val_accuracy: 0.9331 - lr: 0.0100
# Epoch 12/50
# 29/29 [==============================] - 0s 16ms/step - loss: 0.2048 - accuracy: 0.9356 - val_loss: 0.1432 - val_accuracy: 0.9574 - lr: 0.0100
# Epoch 13/50
# 29/29 [==============================] - 0s 16ms/step - loss: 0.2301 - accuracy: 0.9269 - val_loss: 0.1432 - val_accuracy: 0.9544 - lr: 0.0100
# Epoch 14/50
# 29/29 [==============================] - 0s 16ms/step - loss: 0.1886 - accuracy: 0.9433 - val_loss: 0.1333 - val_accuracy: 0.9635 - lr: 0.0100
# Epoch 15/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1965 - accuracy: 0.9427 - val_loss: 0.2734 - val_accuracy: 0.9037 - lr: 0.0100
# Epoch 16/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1886 - accuracy: 0.9400 - val_loss: 0.1408 - val_accuracy: 0.9463 - lr: 0.0100
# Epoch 17/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1730 - accuracy: 0.9438 - val_loss: 0.1557 - val_accuracy: 0.9443 - lr: 0.0100
# Epoch 18/50
# 29/29 [==============================] - 0s 16ms/step - loss: 0.1910 - accuracy: 0.9427 - val_loss: 0.1366 - val_accuracy: 0.9554 - lr: 0.0100
# Epoch 19/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1668 - accuracy: 0.9493 - val_loss: 0.1404 - val_accuracy: 0.9585 - lr: 0.0100
# Epoch 20/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1704 - accuracy: 0.9493 - val_loss: 0.1483 - val_accuracy: 0.9433 - lr: 0.0100
# Epoch 21/50
# 29/29 [==============================] - 0s 16ms/step - loss: 0.1642 - accuracy: 0.9525 - val_loss: 0.1260 - val_accuracy: 0.9656 - lr: 0.0100
# Epoch 22/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1436 - accuracy: 0.9580 - val_loss: 0.1280 - val_accuracy: 0.9645 - lr: 0.0100
# Epoch 23/50
# 29/29 [==============================] - 0s 14ms/step - loss: 0.1422 - accuracy: 0.9574 - val_loss: 0.1551 - val_accuracy: 0.9504 - lr: 0.0100
# Epoch 24/50
# 29/29 [==============================] - 0s 16ms/step - loss: 0.1627 - accuracy: 0.9520 - val_loss: 0.1260 - val_accuracy: 0.9666 - lr: 0.0100
# Epoch 25/50
# 29/29 [==============================] - 0s 16ms/step - loss: 0.1482 - accuracy: 0.9569 - val_loss: 0.1152 - val_accuracy: 0.9645 - lr: 0.0100
# Epoch 26/50
# 29/29 [==============================] - 0s 16ms/step - loss: 0.1517 - accuracy: 0.9564 - val_loss: 0.1156 - val_accuracy: 0.9696 - lr: 0.0100
# Epoch 27/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1403 - accuracy: 0.9585 - val_loss: 0.1220 - val_accuracy: 0.9625 - lr: 0.0100
# Epoch 28/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1480 - accuracy: 0.9574 - val_loss: 0.1528 - val_accuracy: 0.9595 - lr: 0.0100
# Epoch 29/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1337 - accuracy: 0.9602 - val_loss: 0.1425 - val_accuracy: 0.9564 - lr: 0.0100
# Epoch 30/50
# 29/29 [==============================] - 0s 16ms/step - loss: 0.1424 - accuracy: 0.9574 - val_loss: 0.1426 - val_accuracy: 0.9625 - lr: 0.0100
# Epoch 31/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1392 - accuracy: 0.9651 - val_loss: 0.1015 - val_accuracy: 0.9737 - lr: 0.0100
# Epoch 32/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1302 - accuracy: 0.9602 - val_loss: 0.1114 - val_accuracy: 0.9676 - lr: 0.0100
# Epoch 33/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1294 - accuracy: 0.9624 - val_loss: 0.1558 - val_accuracy: 0.9524 - lr: 0.0100
# Epoch 34/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1544 - accuracy: 0.9514 - val_loss: 0.1042 - val_accuracy: 0.9676 - lr: 0.0100
# Epoch 35/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1256 - accuracy: 0.9602 - val_loss: 0.1325 - val_accuracy: 0.9645 - lr: 0.0100
# Epoch 36/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1224 - accuracy: 0.9634 - val_loss: 0.1077 - val_accuracy: 0.9706 - lr: 0.0100
# Epoch 37/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1204 - accuracy: 0.9662 - val_loss: 0.1258 - val_accuracy: 0.9615 - lr: 0.0100
# Epoch 38/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1293 - accuracy: 0.9596 - val_loss: 0.1757 - val_accuracy: 0.9625 - lr: 0.0100
# Epoch 39/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1336 - accuracy: 0.9602 - val_loss: 0.1130 - val_accuracy: 0.9666 - lr: 0.0100
# Epoch 40/50
# 29/29 [==============================] - 0s 14ms/step - loss: 0.1309 - accuracy: 0.9607 - val_loss: 0.1279 - val_accuracy: 0.9656 - lr: 0.0100
# Epoch 41/50
# 29/29 [==============================] - 0s 15ms/step - loss: 0.1323 - accuracy: 0.9624 - val_loss: 0.1381 - val_accuracy: 0.9676 - lr: 0.0100

# %%
# Evaluation
def evaluate_model(model, X_test, y_test):
    # Predict on test data
    y_pred = model.predict([X_test, X_test])
    y_pred = np.round(y_pred).astype(int)

    # Calculate accuracy
    accuracy = accuracy_score(y_test, y_pred)
    
    # Calculate precision
    precision = precision_score(y_test, y_pred)
    
    # Calculate recall
    recall = recall_score(y_test, y_pred)
    
    # Calculate F1 score
    f1 = f1_score(y_test, y_pred)
    
    return accuracy, precision, recall, f1

# %%
# Evaluate the model
accuracy, precision, recall, f1 = evaluate_model(hybrid_model, x_test, y_test)
# Out:
# 23/23 [==============================] - 2s 4ms/step

# %%
print("HYBRID MODEL: \n")
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# HYBRID MODEL:
#
# Accuracy: 0.9702127659574468
# Precision: 0.9538461538461539
# Recall: 0.9649805447470817
# F1 Score: 0.9593810444874274

# %%
y_pred = hybrid_model.predict([x_test, x_test])
y_pred = np.round(y_pred).astype(int)

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
    
# Visualize confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.title("Confusion Matrix")
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.show()
# Out:
# 23/23 [==============================] - 0s 5ms/step
